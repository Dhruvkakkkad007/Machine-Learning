# %% [markdown]
# # Student Performance Dataset EDA Practice
# Basic to Intermediate Pandas Questions

# %% [markdown]
# ## Q1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Q2. Read CSV file

# %%
df = pd.read_excel('student_performance_dataset_1.csv.xlsx')
df
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0              1   20  Female    1st Year                  2.5        1
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %% [markdown]
# ## Q3. Display first 10 records

# %%
df.head(10)
# Out:
#    student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0           1   20  Female    1st Year                  2.5        1
# 1           2   17    Male        12th                  3.4        1
# 2           3   24    Male    3rd Year                  0.8        0
# 3           4   21  Female        12th                  4.4        0
# 4           5   18   Other    3rd Year                  3.5        1
# 5           6   20    Male    1st Year                  5.1        1
# 6           7   23  Female    1st Year                  2.0        1
# 7           8   16    Male    3rd Year                  5.5        0
# 8           9   20  Female        10th                  6.0        1
# 9          10   24  Female    1st Year                  5.6        0
#
#    ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# 0                    170             NaN        Exam Prep
# 1                    123             NaN            Notes
# ...

# %% [markdown]
# ## Q4. Display last 10 records

# %%
df.tail(10)
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 7990        7991   15    Male        11th                  5.9        1
# 7991        7992   15  Female        10th                  4.8        0
# 7992        7993   18  Female    3rd Year                  3.4        1
# 7993        7994   23    Male    1st Year                  2.9        1
# 7994        7995   23    Male        11th                  3.5        1
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes ai_tools_used ai_usage_purpose  \
# 7990                     15           NaN    Doubt Solving
# ...

# %% [markdown]
# ## Q5. Display shape

# %%
df.shape
# Out:
# (8000, 26)

# %% [markdown]
# ## Q6. Display columns

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'grade_level', 'study_hours_per_day',
#        'uses_ai', 'ai_usage_time_minutes', 'ai_tools_used', 'ai_usage_purpose',
#        'ai_dependency_score', 'ai_generated_content_percentage',
#        'ai_prompts_per_week', 'ai_ethics_score', 'last_exam_score',
#        'assignment_scores_avg', 'attendance_percentage',
#        'concept_understanding_score', 'study_consistency_index',
#        'improvement_rate', 'sleep_hours', 'social_media_hours',
#        'tutoring_hours', 'class_participation_score', 'final_score', 'passed',
#        'performance_category'],
#       dtype='object')

# %% [markdown]
# ## Q7. Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   student_id                       8000 non-null   int64
#  1   age                              8000 non-null   int64
#  2   gender                           8000 non-null   object
#  3   grade_level                      8000 non-null   object
#  4   study_hours_per_day              8000 non-null   float64
#  5   uses_ai                          8000 non-null   int64
#  6   ai_usage_time_minutes            8000 non-null   int64
#  7   ai_tools_used                    6638 non-null   object
#  8   ai_usage_purpose                 6654 non-null   object
#  9   ai_dependency_score              8000 non-null   int64
#  10  ai_generated_content_percentage  8000 non-null   int64
#  11  ai_prompts_per_week              8000 non-null   int64
# ...

# %% [markdown]
# ## Q8. Summary statistics

# %%
df.describe()
# Out:
#        student_id         age  study_hours_per_day      uses_ai  \
# count  8000.00000  8000.00000          8000.000000  8000.000000
# mean   4000.50000    18.96725             3.286938     0.641000
# std    2309.54541     3.15316             1.582171     0.479737
# min       1.00000    14.00000             0.500000     0.000000
# 25%    2000.75000    16.00000             1.900000     0.000000
# 50%    4000.50000    19.00000             3.300000     1.000000
# 75%    6000.25000    22.00000             4.600000     1.000000
# max    8000.00000    24.00000             6.000000     1.000000
#
#        ai_usage_time_minutes  ai_dependency_score  \
# count            8000.000000          8000.000000
# mean               88.989875             5.515125
# std                52.184077             2.883064
# min                 0.000000             1.000000
# 25%                43.000000             3.000000
# 50%                89.000000             6.000000
# ...

# %% [markdown]
# ## Q9. Check data types

# %%
df.dtypes
# Out:
# student_id                           int64
# age                                  int64
# gender                              object
# grade_level                         object
# study_hours_per_day                float64
# uses_ai                              int64
# ai_usage_time_minutes                int64
# ai_tools_used                       object
# ai_usage_purpose                    object
# ai_dependency_score                  int64
# ai_generated_content_percentage      int64
# ai_prompts_per_week                  int64
# ai_ethics_score                      int64
# last_exam_score                      int64
# assignment_scores_avg              float64
# attendance_percentage              float64
# concept_understanding_score          int64
# study_consistency_index            float64
# improvement_rate                   float64
# sleep_hours                        float64
# social_media_hours                 float64
# tutoring_hours                     float64
# ...

# %% [markdown]
# ## Q10. Count missing values

# %%
df.isnull().sum()
# Out:
# student_id                            0
# age                                   0
# gender                                0
# grade_level                           0
# study_hours_per_day                   0
# uses_ai                               0
# ai_usage_time_minutes                 0
# ai_tools_used                      1362
# ai_usage_purpose                   1346
# ai_dependency_score                   0
# ai_generated_content_percentage       0
# ai_prompts_per_week                   0
# ai_ethics_score                       0
# last_exam_score                       0
# assignment_scores_avg                 0
# attendance_percentage                 0
# concept_understanding_score           0
# study_consistency_index               0
# improvement_rate                      0
# sleep_hours                           0
# social_media_hours                    0
# tutoring_hours                        0
# class_participation_score             0
# ...

# %% [markdown]
# ## Q11. Count duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Q12. Remove duplicates

# %%
df.drop_duplicates()
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 0              1   20  Female    1st Year                  2.5        1
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %% [markdown]
# ## Q13. Unique values in performance_category

# %%
df['performance_category'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %% [markdown]
# ## Q14. Value counts

# %%
df['performance_category'].value_counts()
# Out:
# performance_category
# Medium    4705
# Low       2542
# High       753
# Name: count, dtype: int64

# %% [markdown]
# ## Q15. Mean final score

# %%
df['final_score'].mean()
# Out:
# np.float64(56.8119875)

# %% [markdown]
# ## Q16. Median final score

# %%
df['final_score'].median()
# Out:
# 56.9

# %% [markdown]
# ## Q17. Maximum final score

# %%
df['final_score'].max()
# Out:
# 95.8

# %% [markdown]
# ## Q18. Minimum final score

# %%
df['final_score'].min()
# Out:
# 12.7

# %% [markdown]
# ## Q19. Students passed

# %%
df[df['passed']==1]
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 1              2   17    Male        12th                  3.4        1
# 2              3   24    Male    3rd Year                  0.8        0
# 3              4   21  Female        12th                  4.4        0
# 4              5   18   Other    3rd Year                  3.5        1
# 5              6   20    Male    1st Year                  5.1        1
# ...          ...  ...     ...         ...                  ...      ...
# 7995        7996   23    Male    3rd Year                  3.0        0
# 7996        7997   21   Other    1st Year                  3.3        0
# 7997        7998   24    Male    3rd Year                  1.6        0
# 7998        7999   22  Female    2nd Year                  5.5        0
# 7999        8000   15    Male        12th                  4.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %% [markdown]
# ## Q20. Average attendance

# %%
df['attendance_percentage'].mean()
# Out:
# np.float64(69.85211249999999)

# %% [markdown]
# ## Q21. Correlation matrix

# %%
df.corr(numeric_only=True)
# Out:
#                                  student_id       age  study_hours_per_day  \
# student_id                         1.000000  0.016347            -0.018194
# age                                0.016347  1.000000            -0.020504
# study_hours_per_day               -0.018194 -0.020504             1.000000
# uses_ai                            0.020702  0.006359            -0.009835
# ai_usage_time_minutes              0.013013 -0.004758             0.002130
# ai_dependency_score                0.025216 -0.002380             0.004208
# ai_generated_content_percentage   -0.014774 -0.003763             0.003263
# ai_prompts_per_week                0.018575 -0.034365             0.000951
# ai_ethics_score                    0.005220 -0.013394             0.002007
# last_exam_score                   -0.001756  0.010088             0.009136
# assignment_scores_avg              0.000307 -0.008140            -0.007500
# ...

# %% [markdown]
# ## Q22. Group by learner type

# %%
df.groupby('performance_category')['final_score'].mean()
# Out:
# performance_category
# High      80.696547
# Low       41.540637
# Medium    61.240191
# Name: final_score, dtype: float64

# %% [markdown]
# ## Q23. Sort by final score desc

# %%
df.sort_values('final_score', ascending=False)
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 7719        7720   21  Female        11th                  0.7        1
# 7980        7981   22    Male        10th                  4.9        1
# 4028        4029   24  Female        10th                  2.1        1
# 1863        1864   23  Female    2nd Year                  4.7        1
# 5302        5303   24    Male        10th                  5.0        1
# ...          ...  ...     ...         ...                  ...      ...
# 4529        4530   19    Male    3rd Year                  5.6        1
# 2183        2184   20    Male        12th                  0.8        1
# 6082        6083   16    Male        11th                  4.9        0
# 3328        3329   24    Male    1st Year                  5.4        1
# 785          786   24  Female        12th                  3.4        1
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# ...

# %% [markdown]
# ## Q24. Top 10 performers

# %%
# Method 1
# df.nlargest(10,'final_score')

#Method 2
df.sort_values("final_score", ascending=False).head(10)
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 7719        7720   21  Female        11th                  0.7        1
# 7980        7981   22    Male        10th                  4.9        1
# 4028        4029   24  Female        10th                  2.1        1
# 1863        1864   23  Female    2nd Year                  4.7        1
# 5302        5303   24    Male        10th                  5.0        1
# 5229        5230   15    Male    3rd Year                  4.9        1
# 2160        2161   18  Female    3rd Year                  4.1        1
# 5477        5478   20    Male        11th                  1.5        1
# 6497        6498   21  Female        10th                  4.3        1
# 7011        7012   23    Male    1st Year                  3.6        1
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# 7719                    130         ChatGPT           Coding
# ...

# %% [markdown]
# ## Q25. Bottom 10 performers

# %%
#Method 1
# df.nsmallest(10,'final_score')

#Method 2
df.sort_values("final_score", ascending=True).head(10)
# Out:
#       student_id  age  gender grade_level  study_hours_per_day  uses_ai  \
# 785          786   24  Female        12th                  3.4        1
# 3328        3329   24    Male    1st Year                  5.4        1
# 6082        6083   16    Male        11th                  4.9        0
# 2183        2184   20    Male        12th                  0.8        1
# 6642        6643   23  Female        12th                  1.3        1
# 4529        4530   19    Male    3rd Year                  5.6        1
# 5160        5161   23    Male    2nd Year                  4.2        1
# 5495        5496   19  Female    1st Year                  0.7        0
# 7982        7983   20    Male        12th                  5.4        1
# 2066        2067   24  Female    2nd Year                  2.6        0
#
#       ai_usage_time_minutes   ai_tools_used ai_usage_purpose  \
# 785                      23  ChatGPT+Gemini    Doubt Solving
# ...
